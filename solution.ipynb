# %% [markdown]
# Importación de librerías base para el problema

# %%
import pandas as pd
import datetime as dt
import numpy as np
import sklearn as sk
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import plotly.express as px
import os
import openpyxl


os.getcwd()
# Out:
# 'c:\\Users\\shado\\OneDrive\\Escritorio\\Latam\\LATAM'

# %% [markdown]
# ##### Esta sección del codigo hace que los graficos dinamicos de pyplot queden estaticos para las vista en github.

# %%
import plotly.io as pio
pio.renderers
pio.renderers.default = "svg"

# %% [markdown]
# # 2.- Genera las columnas adicionales y luego expórtelas en un archivo synthetic_features.csv :

# %% [markdown]
# #### Se inició por la segunda parte antes que el primer punto, ya que también analizare las variables agregadas externas al dataframe, por esta razón el punto 1 y 3 de análisis se estarán más abajo.

# %% [markdown]
# #### Lectura de datos principal y creacion de copia auxiliar de de la data original, también se busco información extra sobre países de los destinos de vuelos y los días feriados de ese año para el origen de los vuelos

# %% [markdown]
# #### Lectura y creación de variables en el data frame

# %%
datos = pd.read_csv("dataset_SCL.csv", sep=",", low_memory=False)
datos_original = datos.copy()
paises =  pd.read_excel("Prefijo Paises.xlsx", sheet_name= 'Hoja2')
feriados =  pd.read_excel("Feriados.xlsx")
datos.columns
# Out:
# Index(['Fecha-I', 'Vlo-I', 'Ori-I', 'Des-I', 'Emp-I', 'Fecha-O', 'Vlo-O',
#        'Ori-O', 'Des-O', 'Emp-O', 'DIA', 'MES', 'AÑO', 'DIANOM', 'TIPOVUELO',
#        'OPERA', 'SIGLAORI', 'SIGLADES'],
#       dtype='object')

# %% [markdown]
# #### Verificación de tipos de datos en el data frame

# %%
datos.dtypes
# Out:
# Fecha-I      object
# Vlo-I        object
# Ori-I        object
# Des-I        object
# Emp-I        object
# Fecha-O      object
# Vlo-O        object
# Ori-O        object
# Des-O        object
# Emp-O        object
# DIA           int64
# MES           int64
# AÑO           int64
# DIANOM       object
# TIPOVUELO    object
# OPERA        object
# SIGLAORI     object
# SIGLADES     object
# dtype: object

# %% [markdown]
# transformanción de Fechas a formato tiempo

# %%
datos["Fecha-I"] = pd.to_datetime(datos["Fecha-I"])
datos["Fecha-O"] = pd.to_datetime(datos["Fecha-O"])
datos.dtypes
# Out:
# Fecha-I      datetime64[ns]
# Vlo-I                object
# Ori-I                object
# Des-I                object
# Emp-I                object
# Fecha-O      datetime64[ns]
# Vlo-O                object
# Ori-O                object
# Des-O                object
# Emp-O                object
# DIA                   int64
# MES                   int64
# AÑO                   int64
# DIANOM               object
# TIPOVUELO            object
# OPERA                object
# SIGLAORI             object
# SIGLADES             object
# dtype: object

# %% [markdown]
# creación de variables dif_min, hora_dia, hora, minutos

# %%
datos['dif_min'] = (datos["Fecha-O"]- datos["Fecha-I"])
datos['hora_dia'] = datos['Fecha-I'].dt.time
datos['hora'] = datos['Fecha-I'].dt.hour
datos['minutos'] = datos['Fecha-I'].dt.minute

datos.head()
# Out:
#               Fecha-I Vlo-I Ori-I Des-I Emp-I             Fecha-O Vlo-O Ori-O  \
# 0 2017-01-01 23:30:00   226  SCEL  KMIA   AAL 2017-01-01 23:33:00   226  SCEL
# 1 2017-01-02 23:30:00   226  SCEL  KMIA   AAL 2017-01-02 23:39:00   226  SCEL
# 2 2017-01-03 23:30:00   226  SCEL  KMIA   AAL 2017-01-03 23:39:00   226  SCEL
# 3 2017-01-04 23:30:00   226  SCEL  KMIA   AAL 2017-01-04 23:33:00   226  SCEL
# 4 2017-01-05 23:30:00   226  SCEL  KMIA   AAL 2017-01-05 23:28:00   226  SCEL
#
#   Des-O Emp-O  ...   AÑO     DIANOM  TIPOVUELO              OPERA  SIGLAORI  \
# 0  KMIA   AAL  ...  2017    Domingo          I  American Airlines  Santiago
# 1  KMIA   AAL  ...  2017      Lunes          I  American Airlines  Santiago
# 2  KMIA   AAL  ...  2017     Martes          I  American Airlines  Santiago
# 3  KMIA   AAL  ...  2017  Miercoles          I  American Airlines  Santiago
# 4  KMIA   AAL  ...  2017     Jueves          I  American Airlines  Santiago
#
#   SIGLADES           dif_min  hora_dia hora minutos
# 0    Miami   0 days 00:03:00  23:30:00   23      30
# 1    Miami   0 days 00:09:00  23:30:00   23      30
# 2    Miami   0 days 00:09:00  23:30:00   23      30
# 3    Miami   0 days 00:03:00  23:30:00   23      30
# 4    Miami -1 days +23:58:00  23:30:00   23      30
#
# [5 rows x 22 columns]

# %% [markdown]
# cambia la diferencia de las fechas de programación y salida de los vuelos a minutos.

# %%
datos["dif_min"] =  datos["dif_min"]/np.timedelta64(1,'m')

# %% [markdown]
# Homologación de variable Mes a nombre

# %%
conditions = [
    (datos['MES'] == 1),
    (datos['MES'] == 2),
    (datos['MES'] == 3),
    (datos['MES'] == 4),
    (datos['MES'] == 5),
    (datos['MES'] == 6),
    (datos['MES'] == 7),
    (datos['MES'] == 8),
    (datos['MES'] == 9),
    (datos['MES'] == 10),
    (datos['MES'] == 11),
    (datos['MES'] == 12)]
values = [
    'Enero',
    'Febrero',
    'Marzo',
    'Abril',
    'Mayo',
    'Junio',
    'Julio',
    'Agosto',
    'Septiembre',
    'Octubre',
    'Noviembre',
    'Diciembre']
datos['Mes_Nombre'] = np.select(conditions, values)
datos.head()
# Out:
#               Fecha-I Vlo-I Ori-I Des-I Emp-I             Fecha-O Vlo-O Ori-O  \
# 0 2017-01-01 23:30:00   226  SCEL  KMIA   AAL 2017-01-01 23:33:00   226  SCEL
# 1 2017-01-02 23:30:00   226  SCEL  KMIA   AAL 2017-01-02 23:39:00   226  SCEL
# 2 2017-01-03 23:30:00   226  SCEL  KMIA   AAL 2017-01-03 23:39:00   226  SCEL
# 3 2017-01-04 23:30:00   226  SCEL  KMIA   AAL 2017-01-04 23:33:00   226  SCEL
# 4 2017-01-05 23:30:00   226  SCEL  KMIA   AAL 2017-01-05 23:28:00   226  SCEL
#
#   Des-O Emp-O  ...     DIANOM  TIPOVUELO              OPERA  SIGLAORI  \
# 0  KMIA   AAL  ...    Domingo          I  American Airlines  Santiago
# 1  KMIA   AAL  ...      Lunes          I  American Airlines  Santiago
# 2  KMIA   AAL  ...     Martes          I  American Airlines  Santiago
# 3  KMIA   AAL  ...  Miercoles          I  American Airlines  Santiago
# 4  KMIA   AAL  ...     Jueves          I  American Airlines  Santiago
#
#   SIGLADES dif_min  hora_dia hora  minutos Mes_Nombre
# 0    Miami     3.0  23:30:00   23       30      Enero
# 1    Miami     9.0  23:30:00   23       30      Enero
# 2    Miami     9.0  23:30:00   23       30      Enero
# 3    Miami     3.0  23:30:00   23       30      Enero
# 4    Miami    -2.0  23:30:00   23       30      Enero
#
# [5 rows x 23 columns]

# %% [markdown]
# Verificación que los valores esten correctos

# %%
datos[["dif_min","Fecha-O","Fecha-I"]]
# Out:
#        dif_min             Fecha-O             Fecha-I
# 0          3.0 2017-01-01 23:33:00 2017-01-01 23:30:00
# 1          9.0 2017-01-02 23:39:00 2017-01-02 23:30:00
# 2          9.0 2017-01-03 23:39:00 2017-01-03 23:30:00
# 3          3.0 2017-01-04 23:33:00 2017-01-04 23:30:00
# 4         -2.0 2017-01-05 23:28:00 2017-01-05 23:30:00
# ...        ...                 ...                 ...
# 68201     46.0 2017-12-22 15:41:00 2017-12-22 14:55:00
# 68202     16.0 2017-12-25 15:11:00 2017-12-25 14:55:00
# 68203     40.0 2017-12-27 15:35:00 2017-12-27 14:55:00
# 68204     13.0 2017-12-29 15:08:00 2017-12-29 14:55:00
# 68205      9.0 2017-12-31 15:04:00 2017-12-31 14:55:00
#
# [68206 rows x 3 columns]

# %% [markdown]
# Creación de variable temporada_alta y atraso_15

# %%
datos['temporada_alta'] = np.where(  ((datos['Fecha-I']>='2017-12-15') & (datos['Fecha-I']<='2018-03-03')) 
                                   | ((datos['Fecha-I']>='2017-07-15') & (datos['Fecha-I']<='2017-07-31'))
                                   | ((datos['Fecha-I']>='2017-01-01') & (datos['Fecha-I']<='2017-03-03'))
                                   | ((datos['Fecha-I']>='2017-09-11') & (datos['Fecha-I']<='2017-09-30'))
                                   ,1,0)
datos['atraso_15'] = np.where(datos['dif_min']>15,1,0)

# %% [markdown]
# #### creacion de variable periodo_dia

# %%
conditions = [
    (datos['hora'] >= 5) & (datos['hora'] < 12),
    (datos['hora'] >= 12) & (datos['hora'] < 19),
    (datos['hora'] >= 19) | ((datos['hora'] >= 0) & (datos['hora'] < 5))]
values = ['mañana', 'tarde', 'noche']
datos['periodo_dia'] = np.select(conditions, values)

# %% [markdown]
# ##### Creación Variable Destino, la cual agrupa Destino de operación cuales tengan menos de 10 vuelos en categoria Otros

# %%
Destino_pre = datos.groupby(['Des-O']
                          #'OPERA',
                          #'MES',
                          #'DIA',
                          #'temporada_alta'
                        , dropna=False, as_index= False).agg(
    Cantidad_Vuelos = ('atraso_15','count'))


Destino_menores = Destino_pre[Destino_pre['Cantidad_Vuelos']<=10]

flex = Destino_menores['Des-O'].to_list() #agrega lista de destinos con menos de 10 vuelos
datos['Destino'] = np.where(datos['Des-O'].isin(flex), 'Otro',datos['Des-O']) #Creación de variable Destino donde se agrupan los DES-O con menos de 10 vuelos en categoria Otros

# %% [markdown]
# #### Creación de variable País

# %%
paises['Des-O_2'] = paises['Código prefijo']
paises['Largo'] = paises['Des-O_2'].str.len()

paises_1 = paises[paises['Largo'] == 1]
paises_2 = paises[paises['Largo'] == 2]

def subs(x):
    return x[:2]
datos['Des-O_2'] = datos['Des-O'].apply(subs)
datos['Des-O_2']
paises_2 = paises_2.drop(columns=['Largo','Código prefijo'], axis=1)
paises_1 = paises_1.drop(columns=['Largo','Código prefijo'], axis=1)

# %% [markdown]
# ##### se crean dos set de datos uno con los paises de prefijo largo 1 y otro con los paises de prefijo largo 2, se trabajan por separado y luego se juntan solo en el data frame de datos.

# %%
datos_test = datos.merge(paises_2, how='left', left_on='Des-O_2', right_on = 'Des-O_2')
datos_1 = datos_test[datos_test['País'].isnull()]
datos_2 = datos_test[datos_test['País'].notnull()]

datos_1 =  datos_1.drop(columns=[ 'País', ], axis=1)

def subs(x):
    return x[:1]
datos_1['Des-O_2'] = datos_1['Des-O'].apply(subs)
datos_1['Des-O_2']

datos_1 = datos_1.merge(paises_1, how='left', left_on='Des-O_2', right_on = 'Des-O_2')
datos_test = pd.concat([datos_1, datos_2], axis = 0)

datos_test =  datos_test.drop(columns=['LARGO_x','LARGO_y', 'LARGO'], axis=1)

datos_test =  datos_test.drop(columns=[ 'Des-O_2', ], axis=1)
datos_test
# Out:
#                   Fecha-I Vlo-I Ori-I Des-I Emp-I             Fecha-O  Vlo-O  \
# 0     2017-01-01 23:30:00   226  SCEL  KMIA   AAL 2017-01-01 23:33:00    226
# 1     2017-01-02 23:30:00   226  SCEL  KMIA   AAL 2017-01-02 23:39:00    226
# 2     2017-01-03 23:30:00   226  SCEL  KMIA   AAL 2017-01-03 23:39:00    226
# 3     2017-01-04 23:30:00   226  SCEL  KMIA   AAL 2017-01-04 23:33:00    226
# 4     2017-01-05 23:30:00   226  SCEL  KMIA   AAL 2017-01-05 23:28:00    226
# ...                   ...   ...   ...   ...   ...                 ...    ...
# 68201 2017-12-22 14:55:00   400  SCEL  SPJC   JAT 2017-12-22 15:41:00  400.0
# 68202 2017-12-25 14:55:00   400  SCEL  SPJC   JAT 2017-12-25 15:11:00  400.0
# 68203 2017-12-27 14:55:00   400  SCEL  SPJC   JAT 2017-12-27 15:35:00  400.0
# 68204 2017-12-29 14:55:00   400  SCEL  SPJC   JAT 2017-12-29 15:08:00  400.0
# 68205 2017-12-31 14:55:00   400  SCEL  SPJC   JAT 2017-12-31 15:04:00  400.0
#
#       Ori-O Des-O Emp-O  ...  dif_min  hora_dia  hora minutos Mes_Nombre  \
# 0      SCEL  KMIA   AAL  ...      3.0  23:30:00    23      30      Enero
# 1      SCEL  KMIA   AAL  ...      9.0  23:30:00    23      30      Enero
# 2      SCEL  KMIA   AAL  ...      9.0  23:30:00    23      30      Enero
# 3      SCEL  KMIA   AAL  ...      3.0  23:30:00    23      30      Enero
# 4      SCEL  KMIA   AAL  ...     -2.0  23:30:00    23      30      Enero
# ...     ...   ...   ...  ...      ...       ...   ...     ...        ...
# 68201  SCEL  SPJC   JAT  ...     46.0  14:55:00    14      55  Diciembre
# 68202  SCEL  SPJC   JAT  ...     16.0  14:55:00    14      55  Diciembre
# 68203  SCEL  SPJC   JAT  ...     40.0  14:55:00    14      55  Diciembre
# 68204  SCEL  SPJC   JAT  ...     13.0  14:55:00    14      55  Diciembre
# 68205  SCEL  SPJC   JAT  ...      9.0  14:55:00    14      55  Diciembre
#
#       temporada_alta atraso_15 periodo_dia  Destino  \
# 0                  1         0       noche     KMIA
# 1                  1         0       noche     KMIA
# 2                  1         0       noche     KMIA
# 3                  1         0       noche     KMIA
# 4                  1         0       noche     KMIA
# ...              ...       ...         ...      ...
# 68201              1         1       tarde     SPJC
# 68202              1         1       tarde     SPJC
# 68203              1         1       tarde     SPJC
# 68204              1         0       tarde     SPJC
# 68205              1         0       tarde     SPJC
#
#                                           País
# 0      Estados contiguos de los Estados Unidos
# 1      Estados contiguos de los Estados Unidos
# 2      Estados contiguos de los Estados Unidos
# 3      Estados contiguos de los Estados Unidos
# 4      Estados contiguos de los Estados Unidos
# ...                                        ...
# 68201                                     Perú
# 68202                                     Perú
# 68203                                     Perú
# 68204                                     Perú
# 68205                                     Perú
#
# [68206 rows x 28 columns]

# %% [markdown]
# #### Creación de una variable con los dias Feriados en el data frame.

# %%
datos_test['Fecha-I'] = datos_test['Fecha-I'].dt.normalize()
datos_test = datos_test.merge(feriados, how='left', left_on='Fecha-I', right_on = 'Fecha-I')
datos_test['Feriado'] = np.where(datos_test['Feriado'].isnull(),'No Feriado','Feriado')
datos_test
# Out:
#          Fecha-I Vlo-I Ori-I Des-I Emp-I             Fecha-O  Vlo-O Ori-O  \
# 0     2017-01-01   226  SCEL  KMIA   AAL 2017-01-01 23:33:00    226  SCEL
# 1     2017-01-02   226  SCEL  KMIA   AAL 2017-01-02 23:39:00    226  SCEL
# 2     2017-01-03   226  SCEL  KMIA   AAL 2017-01-03 23:39:00    226  SCEL
# 3     2017-01-04   226  SCEL  KMIA   AAL 2017-01-04 23:33:00    226  SCEL
# 4     2017-01-05   226  SCEL  KMIA   AAL 2017-01-05 23:28:00    226  SCEL
# ...          ...   ...   ...   ...   ...                 ...    ...   ...
# 68201 2017-12-22   400  SCEL  SPJC   JAT 2017-12-22 15:41:00  400.0  SCEL
# 68202 2017-12-25   400  SCEL  SPJC   JAT 2017-12-25 15:11:00  400.0  SCEL
# 68203 2017-12-27   400  SCEL  SPJC   JAT 2017-12-27 15:35:00  400.0  SCEL
# 68204 2017-12-29   400  SCEL  SPJC   JAT 2017-12-29 15:08:00  400.0  SCEL
# 68205 2017-12-31   400  SCEL  SPJC   JAT 2017-12-31 15:04:00  400.0  SCEL
#
#       Des-O Emp-O  ...  hora_dia  hora  minutos Mes_Nombre temporada_alta  \
# 0      KMIA   AAL  ...  23:30:00    23       30      Enero              1
# 1      KMIA   AAL  ...  23:30:00    23       30      Enero              1
# 2      KMIA   AAL  ...  23:30:00    23       30      Enero              1
# 3      KMIA   AAL  ...  23:30:00    23       30      Enero              1
# 4      KMIA   AAL  ...  23:30:00    23       30      Enero              1
# ...     ...   ...  ...       ...   ...      ...        ...            ...
# 68201  SPJC   JAT  ...  14:55:00    14       55  Diciembre              1
# 68202  SPJC   JAT  ...  14:55:00    14       55  Diciembre              1
# 68203  SPJC   JAT  ...  14:55:00    14       55  Diciembre              1
# 68204  SPJC   JAT  ...  14:55:00    14       55  Diciembre              1
# 68205  SPJC   JAT  ...  14:55:00    14       55  Diciembre              1
#
#       atraso_15 periodo_dia Destino                                     País  \
# 0             0       noche    KMIA  Estados contiguos de los Estados Unidos
# 1             0       noche    KMIA  Estados contiguos de los Estados Unidos
# 2             0       noche    KMIA  Estados contiguos de los Estados Unidos
# 3             0       noche    KMIA  Estados contiguos de los Estados Unidos
# 4             0       noche    KMIA  Estados contiguos de los Estados Unidos
# ...         ...         ...     ...                                      ...
# 68201         1       tarde    SPJC                                     Perú
# 68202         1       tarde    SPJC                                     Perú
# 68203         1       tarde    SPJC                                     Perú
# 68204         0       tarde    SPJC                                     Perú
# 68205         0       tarde    SPJC                                     Perú
#
#           Feriado
# 0         Feriado
# 1      No Feriado
# 2      No Feriado
# 3      No Feriado
# 4      No Feriado
# ...           ...
# 68201  No Feriado
# 68202     Feriado
# 68203  No Feriado
# 68204  No Feriado
# 68205  No Feriado
#
# [68206 rows x 29 columns]

# %% [markdown]
# #### exportación de archivo csv con las variables creadas desde el dataframe

# %%
synthetic_features = datos_test[[
            'temporada_alta'
            ,'dif_min'
            ,'atraso_15'
            ,'periodo_dia'
            ,'Destino'
            ,'País'
            ,'Feriado'
            ]]

synthetic_features.to_csv("synthetic_features.csv"
                          , sep="|"
                          , header=True
                          , index=False)

# %% [markdown]
# # En esta seccion se respondera tanto la Pregunta N° 1 como la N° 3 conjuntamente, analizando la distribucion de la variable atraso y el impacto de las otras variables sobre esta.

# %% [markdown]
# ## 1.- ¿Cómo se distribuyen los datos? ¿Qué te llama la atención o cuál es tu conclusión sobre esto?
#
# ## 3.-   ¿Cómo se compone la tasa de atraso por destino, aerolínea, mes del año, día de la semana, temporada, tipo de vuelo?
# ##       ¿Qué variables esperarías que más influyeran en predecir atrasos?

# %% [markdown]
# ## Distribución de atrasos y adelantos

# %%
hist_min_dif = px.histogram(datos_test, x="dif_min",
                   title='Histograma minutos de diferencia',
                   labels={'dif_min':'total bill'}, 
                   opacity=0.7,
                   color_discrete_sequence=['#FF2800'] 
                   )
hist_min_dif.update_traces(marker_line_width = 1
                  ,marker_line_color = 'black')


hist_min_dif.show()

# %% [markdown]
# #### Al verificar distribución de la variable Minutos de diferencia entre la programación del vuelo y la salida de este. observamos que la data se encuentra cargada a la izquierda con valores negativos, lo que nos dice que existen algunos vuelos que salen antes de lo programado. Para nuestro ejemplo nos centraremos en analizar los datos que presentan atrasos ya que es la variable que intentaremos predecir posteriormente.
#
# #### A priori observamos que si bien la distribución es asimetrica positiva, no vemos grandes problemas o cumulos de datos outliers, ya que su cola a pesar de ser larga no concentra un gran número de casos.

# %% [markdown]
# ## Distribución de atrasos

# %%
atrasos = datos[datos['atraso_15']==1] #filtro para ver histograma solo de vuelos con atrasos


fig = px.histogram(atrasos
                   , x="dif_min"
                   ,title='Histograma minutos de diferencia'
                   ,labels={'dif_min':'total bill'}
                   ,opacity=0.8
                   ,color_discrete_sequence=['#FF2800'] )

fig.update_traces(marker_line_width = 1
                  ,marker_line_color = 'black')
fig.show()

# %% [markdown]
# #### Se observa a través del gráfico que la variable distribuye probabilisticamente de forma exponencial, verificaremos esto a través de un test de bondad de ajuste.

# %% [markdown]
# ### En la siguiente sección se entregaran diversas estadísticas descriptivas y análisis para observar el impacto de las otras variables sobre la tasa de atrasos.

# %% [markdown]
# ### Calculo de tasa de atrasos de la base total y  Gráfico tasa de atrasos en la data completa

# %%
Tasa_atrasos = datos_test.groupby(['atraso_15']
                         # 'Des-O'
                          #'OPERA',
                          #'MES',
                          #'DIA',
                          #'temporada_alta'
                        , dropna=False,as_index=False).agg(
    Cantidad_Vuelos = ('atraso_15','count'))
Tasa_atrasos['Tasa de atrasos'] = (Tasa_atrasos['Cantidad_Vuelos']/68203)*100


def f(row):
    if row == 0:
        val = 'No Atraso'
    else:
        val = 'Atraso'
    return val
Tasa_atrasos['atraso_15'] = Tasa_atrasos['atraso_15'].apply(f)
print(Tasa_atrasos)

fig = px.bar(Tasa_atrasos
             , y ='atraso_15'
             , x ='Tasa de atrasos'
             , color_continuous_scale= 'Bluered'
             , color='Cantidad_Vuelos'
             , orientation= 'h'
             , title = 'Tasa de atrasos'
             , text_auto = True
             )
fig.show()
# Out:
#    atraso_15  Cantidad_Vuelos  Tasa de atrasos
# 0  No Atraso            55592        81.509611
# 1     Atraso            12614        18.494788

# %% [markdown]
# ### Se observa que el 18.49% de los vuelos generales presentan atrasos

# %% [markdown]
# ### Calculo de tasa de atrasos por Destino, se toma en cuenta para esta tasa destinos mayores o iguales a 10 vuelos para la variable Destino de Operacion Des-O

# %%
Destino_pre = datos.groupby(['Des-O']
                          #'OPERA',
                          #'MES',
                          #'DIA',
                          #'temporada_alta'
                        , dropna=False, as_index= False).agg(
    Cantidad_Vuelos = ('atraso_15','count'))


Destino_menores = Destino_pre[Destino_pre['Cantidad_Vuelos']<=10]

flex = Destino_menores['Des-O'].to_list() #agrega lista de destinos con menos de 10 vuelos
datos['Destino'] = np.where(datos['Des-O'].isin(flex), 'Otro',datos['Des-O']) #Creación de variable Destino donde se agrupan los DES-O con menos de 10 vuelos en categoria Otros

# %% [markdown]
# ### Calculo de tasa de atrasos por Destino

# %%
Destino = datos_test.groupby(['Destino']
                          #'OPERA',
                          #'MES',
                          #'DIA',
                          #'temporada_alta'
                        ,as_index=False, dropna=False).agg(
    Cantidad_Vuelos = ('atraso_15','count'),
    Cantidad_Atrasos = ('atraso_15','sum'))
                        
Destino['Tasa de atrasos'] = Destino['Cantidad_Atrasos']/Destino['Cantidad_Vuelos']*100 #Calculo tasa de atrasos
                       
Destino[Destino['Cantidad_Vuelos']>10].sort_values('Tasa de atrasos',ascending=False).head(10)
Destino_mayores = Destino[Destino['Cantidad_Vuelos']>10].sort_values('Tasa de atrasos',ascending=False)
Destino.sort_values('Tasa de atrasos',ascending=False)
# Out:
#    Destino  Cantidad_Vuelos  Cantidad_Atrasos  Tasa de atrasos
# 53    YSSY              194               113        58.247423
# 52    YMML               39                21        53.846154
# 17    Otro               25                10        40.000000
# 18    SAAR              136                54        39.705882
# 16    NZAA              361               135        37.396122
# 12    MDPC               54                18        33.333333
# 0     CYYZ              283                89        31.448763
# 20    SACO             1023               308        30.107527
# 46    SGAS              232                66        28.448276
# 27    SBGL             1435               405        28.222997
# 22    SAME             1625               443        27.261538
# 19    SABE             3094               827        26.729153
# 7     KMCO               34                 9        26.470588
# 23    SANT               38                10        26.315789
# 47    SKBO             1604               415        25.872818
# 6     KLAX              155                39        25.161290
# 49    SLVR              120                30        25.000000
# 28    SBGR             3569               881        24.684786
# 21    SAEZ             3241               793        24.467757
# 50    SPJC             5270              1214        23.036053
# 24    SANU               35                 8        22.857143
# 5     KJFK              382                82        21.465969
# 51    SUMU             1066               220        20.637899
# 37    SCIP              452                89        19.690265
# 45    SEGU              422                82        19.431280
# 38    SCJO              259                50        19.305019
# 8     KMIA             1016               194        19.094488
# 14    MMUN               63                12        19.047619
# 9     LEMD              894               170        19.015660
# 26    SBFL              162                30        18.518519
# 34    SCDA             3747               640        17.080331
# 43    SCTE             4357               734        16.846454
# 42    SCSE             2410               390        16.182573
# 36    SCIE             3993               623        15.602304
# 41    SCQP             2589               403        15.565856
# 44    SCVD              753               117        15.537849
# 33    SCCI             2105               324        15.391924
# 48    SLLP              209                32        15.311005
# 31    SCBA              839               123        14.660310
# 35    SCFA             5786               847        14.638783
# 1     EGLL              205                29        14.146341
# 30    SCAT             1780               242        13.595506
# 29    SCAR             2436               330        13.546798
# 32    SCCF             5146               629        12.223086
# 11    LIRF              259                29        11.196911
# 25    SAZN               37                 4        10.810811
# 13    MMMX              700                66         9.428571
# 39    SCNT               79                 7         8.860759
# 10    LFPG              359                31         8.635097
# 40    SCPQ              235                18         7.659574
# 3     KDFW              357                25         7.002801
# 15    MPTO             1850               116         6.270270
# 2     KATL              358                21         5.865922
# 4     KIAH              334                17         5.089820

# %% [markdown]
# ### Se observa que de los Destinos de operación posibles el que presenta mayor tasa de atrasos es el de YSSY  y YMML ambos en Australia. Una posible hipotesis es agregar la información por país. Es por eso que se incorporó la data externa anteriormente señala.

# %% [markdown]
# ### Grafíco de la tasa de atrasos por Destino

# %%
fig = px.bar(Destino_mayores.head(10).sort_values('Tasa de atrasos',ascending=True)
             , y ='Destino'
             , x ='Tasa de atrasos'
             , color_continuous_scale= 'Bluered'
             , color='Cantidad_Atrasos'
             , orientation= 'h'
             , title = 'Ranking (Top 10) de la Tasa de atrasos por destino segun cantidad de atrasos'
             , text_auto= True
             )
fig.show()

# %% [markdown]
# #### Gráfico de tasa de atrasos segun Destino (Top 10)

# %% [markdown]
# #### ¿es posible saber si Australia es el pais de destino con mayor tasa de atrasos?. Para responder esto usaremos los datos extraidos de  codificacion  Organización de Aviación Civil Internacional "OACI"

# %%
Pais = datos_test.groupby([
                          #'Des-O'
                          #'OPERA',
                          #'MES',
                          #'DIA',
                          'País'
                        ], dropna=False, as_index=False).agg(
    Cantidad_vuelos = ('atraso_15','count'),
    Cantidad_atrasos = ('atraso_15','sum')
                                            )

Pais['Tasa de atrasos'] = (Pais['Cantidad_atrasos']/Pais['Cantidad_vuelos'])*100

Pais = Pais.sort_values('Tasa de atrasos',ascending=False)
Pais
# Out:
#                                               País  Cantidad_vuelos  \
# 1                                        Australia              233
# 13                                   Nueva Zelanda              361
# 18                            República Dominicana               54
# 4                                           Canadá              283
# 15                                        Paraguay              232
# 0                                        Argentina             9237
# 6                                         Colombia             1604
# 3                 Brasil (también SD, SN, SS y SW)             5171
# 16                                            Perú             5271
# 19                                         Uruguay             1072
# 7                                          Ecuador              424
# 2                                          Bolivia              330
# 8       España (excepto Canarias, Ceuta y Melilla)              894
# 5   Chile (también SH para el caso de helipuertos)            36966
# 9          Estados contiguos de los Estados Unidos             2637
# 17                                     Reino Unido              206
# 11                                          Italia              259
# 12                                          México              763
# 10        Francia, incluyendo San Pedro y Miquelón              359
# 14                                          Panamá             1850
#
#     Cantidad_atrasos  Tasa de atrasos
# 1                134        57.510730
# 13               135        37.396122
# 18                18        33.333333
# 4                 89        31.448763
# 15                66        28.448276
# 0               2452        26.545415
# 6                415        25.872818
# 3               1316        25.449623
# 16              1214        23.031683
# 19               221        20.615672
# 7                 84        19.811321
# 2                 63        19.090909
# 8                170        19.015660
# 5               5566        15.057079
# 9                387        14.675768
# 17                30        14.563107
# 11                29        11.196911
# 12                78        10.222805
# 10                31         8.635097
# 14               116         6.270270

# %% [markdown]
# #### Calculamos la tasa de atraso por Pais de destino y podemos obsersvar que efevtivamente Australia es el pais que presenta la mayor tasa de atrasos en los viajes.

# %%
fig = px.bar(Pais.head(15).sort_values('Tasa de atrasos',ascending=True)
            , y='País'
            , x='Tasa de atrasos'
            , color='Cantidad_atrasos'
            , text_auto= True
            )


fig.show()

# %% [markdown]
# #### Se muestran el top 10 de las tasas de atrasos por País.

# %% [markdown]
# #### ¿es posible saber si Australia es el pais de destino con mayor tasa de atrasos?. Para responder esto usaremos los datos extraidos de  codificacion  Organización de Aviación Civil Internacional "OACI"

# %%
Pais = datos_test.groupby([
                          #'Des-O'
                          #'OPERA',
                          #'MES',
                          #'DIA',
                          'País'
                        ], dropna=False, as_index=False).agg(
    Cantidad_vuelos = ('atraso_15','count'),
    Cantidad_atrasos = ('atraso_15','sum')
                                            )

Pais['Tasa de atrasos'] = (Pais['Cantidad_atrasos']/Pais['Cantidad_vuelos'])*100

Pais = Pais.sort_values('Tasa de atrasos',ascending=False)
Pais
# Out:
#                                               País  Cantidad_vuelos  \
# 1                                        Australia              233
# 13                                   Nueva Zelanda              361
# 18                            República Dominicana               54
# 4                                           Canadá              283
# 15                                        Paraguay              232
# 0                                        Argentina             9237
# 6                                         Colombia             1604
# 3                 Brasil (también SD, SN, SS y SW)             5171
# 16                                            Perú             5271
# 19                                         Uruguay             1072
# 7                                          Ecuador              424
# 2                                          Bolivia              330
# 8       España (excepto Canarias, Ceuta y Melilla)              894
# 5   Chile (también SH para el caso de helipuertos)            36966
# 9          Estados contiguos de los Estados Unidos             2637
# 17                                     Reino Unido              206
# 11                                          Italia              259
# 12                                          México              763
# 10        Francia, incluyendo San Pedro y Miquelón              359
# 14                                          Panamá             1850
#
#     Cantidad_atrasos  Tasa de atrasos
# 1                134        57.510730
# 13               135        37.396122
# 18                18        33.333333
# 4                 89        31.448763
# 15                66        28.448276
# 0               2452        26.545415
# 6                415        25.872818
# 3               1316        25.449623
# 16              1214        23.031683
# 19               221        20.615672
# 7                 84        19.811321
# 2                 63        19.090909
# 8                170        19.015660
# 5               5566        15.057079
# 9                387        14.675768
# 17                30        14.563107
# 11                29        11.196911
# 12                78        10.222805
# 10                31         8.635097
# 14               116         6.270270

# %% [markdown]
# #### Calculamos la tasa de atraso por Pais de destino y podemos obsersvar que efevtivamente Australia es el pais que presenta la mayor tasa de atrasos en los viajes.

# %%
fig = px.bar(Pais.head(15).sort_values('Tasa de atrasos',ascending=True)
            , y='País'
            , x='Tasa de atrasos'
            , color='Cantidad_atrasos'
            , text_auto= True
            )


fig.show()

# %% [markdown]
# #### Se muestran el top 10 de las tasas de atrasos por País.

# %% [markdown]
# ### Gráfico de tasa de atrasos por país de Destino coloreado segun la suma de los atrasos. esto nos dice que la la tasa de atrasos mayor la presenta Australia como país, pero la mayor cantidad de atrasos la tiene Chile

# %% [markdown]
# #### Analísis de tasa de atrasos segun tipo de vuelo, Internacional o Nacional.

# %%
Tipo_Vuelo = datos_test.groupby([
                          #'Des-O'
                          #'OPERA',
                          #'MES',
                          #'DIA',
                          'TIPOVUELO'
                        ], dropna=False, as_index=False).agg(
    Cantidad_vuelos = ('atraso_15','count'),
    Cantidad_atrasos = ('atraso_15','sum')
                                            )

Tipo_Vuelo['Tasa de atrasos'] = (Tipo_Vuelo['Cantidad_atrasos']/Tipo_Vuelo['Cantidad_vuelos'])*100




def f(row):
    if row == 'N':
        val = 'Nacional'
    else:
        val = 'Internacional'
    return val
    
Tipo_Vuelo['TIPOVUELO'] = Tipo_Vuelo['TIPOVUELO'].apply(f)
print(Tipo_Vuelo)

fig = px.bar(Tipo_Vuelo.sort_values('Tasa de atrasos',ascending=True), y = 'TIPOVUELO', x = 'Tasa de atrasos', color = 'Cantidad_atrasos',text_auto=True)

fig.update_traces(textfont_size=12
                  , textangle=45
                  , textposition= 'inside'
                  ,marker_line_width=1
                  ,marker_line_color = 'black')

fig.show()
# Out:
#        TIPOVUELO  Cantidad_vuelos  Cantidad_atrasos  Tasa de atrasos
# 0  Internacional            31240              7048        22.560819
# 1       Nacional            36966              5566        15.057079

# %% [markdown]
# ### Se observa que en los Vuelos Nacionales existe un 22.56% de tasa de atrasos vs un 15.05% de tasa de atrasos en los vuelos internacionales. Además del país, este es un candidato para ingresar al modelo

# %% [markdown]
# ## Calculo de Tasa de atrasos por Operador

# %%
Operador = datos.groupby([
                          #'Des-O'
                          'OPERA'
                          #'MES',
                          #'DIA',
                          #'temporada_alta'
                        ], dropna=False, as_index=False).agg(
    Cantidad_Vuelos = ('atraso_15','count'),
    Cantidad_atrasos = ('atraso_15','sum'))
Operador['Tasa de atrasos'] = (Operador['Cantidad_atrasos']/Operador['Cantidad_Vuelos'])*100
Operador = Operador.sort_values('Tasa de atrasos',ascending=False)
(Operador)
# Out:
#                        OPERA  Cantidad_Vuelos  Cantidad_atrasos  \
# 19  Plus Ultra Lineas Aereas               49                30
# 20            Qantas Airways              195               113
# 2                 Air Canada              565               258
# 17      Latin American Wings             1674               681
# 11                 Gol Trans              806               287
# 7                    Avianca             1152               306
# 0      Aerolineas Argentinas             1949               468
# 6                    Austral               74                15
# 14              JetSmart SPA             1095               196
# 12               Grupo LATAM            40892              7306
# 21               Sky Airline            14298              2540
# 18    Oceanair Linhas Aereas              279                43
# 8            British Airways              205                29
# 16                     Lacsa               92                11
# 4                   Alitalia              259                29
# 13                    Iberia              362                36
# 3                 Air France              358                30
# 15                    K.L.M.              251                21
# 5          American Airlines              757                51
# 9                   Copa Air             1850               116
# 10                 Delta Air              358                21
# 22           United Airlines              335                17
# 1                 Aeromexico              351                10
#
#     Tasa de atrasos
# 19        61.224490
# 20        57.948718
# 2         45.663717
# 17        40.681004
# 11        35.607940
# 7         26.562500
# 0         24.012314
# 6         20.270270
# 14        17.899543
# 12        17.866575
# 21        17.764722
# 18        15.412186
# 8         14.146341
# 16        11.956522
# 4         11.196911
# 13         9.944751
# 3          8.379888
# 15         8.366534
# 5          6.737120
# 9          6.270270
# 10         5.865922
# 22         5.074627
# 1          2.849003

# %% [markdown]
# #### En esta sección observamos que el Operador "Plus Ultra Lineas Aereas" presenta la mayor tasa de atrasos con 30 de sus 49 vuelos en total donde los sigue Qantas Airways con 113 de 195 y Air Canada con 258 de 565.

# %% [markdown]
# #### Grafico de tasa de atrasos por operador, coloreado por cantidad de atrasos

# %%
fig = px.bar(Operador.head(15).sort_values('Tasa de atrasos',ascending=True)
            , y='OPERA' 
            ,  x='Tasa de atrasos'
            , color_continuous_scale= 'Bluered'
            , color='Cantidad_atrasos'
            , title= 'Tasa de atrasos por operador según cantidad de atrasos'
            , text_auto= True)
fig.update_traces( marker_line_color = 'black')
fig.show()

# %% [markdown]
# #### Observamos que los 3 Operadores que presentan mayor tasa de atrasos en sus vuelos son Plus Ultra Lineas Aereas, Qantas Airways y Air Canada

# %%
Mes = datos.groupby([
                          #'Des-O'
                          #'OPERA'
                          'Mes_Nombre'
                          #'DIA',
                          #'temporada_alta'
                        ], dropna=False, as_index=False).agg(
    Cantidad_vuelos = ('atraso_15','count'),
    Cantidad_atrasos = ('atraso_15','sum'))
Mes['Tasa de atrasos'] = (Mes['Cantidad_atrasos']/Mes['Cantidad_vuelos'])*100
Mes.sort_values('Tasa de atrasos',ascending=False)
# Out:
#     Mes_Nombre  Cantidad_vuelos  Cantidad_atrasos  Tasa de atrasos
# 5        Julio             5992              1758        29.339119
# 2    Diciembre             6356              1615        25.409062
# 10     Octubre             6032              1363        22.596154
# 9    Noviembre             6080              1199        19.720395
# 1       Agosto             5744               996        17.339833
# 11  Septiembre             5610               967        17.237077
# 6        Junio             4981               852        17.104999
# 3        Enero             6108               978        16.011788
# 8         Mayo             5240               827        15.782443
# 4      Febrero             5561               843        15.159144
# 0        Abril             5020               585        11.653386
# 7        Marzo             5482               631        11.510398

# %% [markdown]
# #### Gráfico de tasa de atrasos por mes, coloreado por cantidad de atrasos

# %%
fig = px.bar(Mes.sort_values('Tasa de atrasos'
                             ,ascending=True)
             , y='Mes_Nombre'
             , x='Tasa de atrasos'
             , color_continuous_scale= 'Bluered'
             , color='Cantidad_atrasos'
             , title= 'Tasa de atrasos por mes, coloreado segun cantidad de atrasos'
             , text_auto= True)
            
fig.update_traces( marker_line_color = 'black')

fig.show()

# %% [markdown]
# ### Podemos observar que el mes que presenta un mayor tasa de atrasos en sus vuelos es el mes de Julio con 29.33% de estos

# %% [markdown]
# ### Estas cantidades en los atrasos del mes de Julio ¿seran observables a nivel diaro?, calcularemos la tasa de atrasos por dia segun la varable Fecha-I

# %%
datos_test['Fecha-I'] = datos_test['Fecha-I'].dt.normalize()

Fechas = datos_test.groupby(['Fecha-I']
                           #'OPERA',
                          #'MES',
                          #'DIA',
                          #,'temporada_alta'
                        , dropna=False, as_index= False).agg(
    Cantidad_vuelos = ('atraso_15','count'),
    Cantidad_atrasos = ('atraso_15','sum'))
                    
Fechas['Tasa de atrasos'] = Fechas['Cantidad_atrasos']/Fechas['Cantidad_vuelos']*100
Fechas.sort_values('Tasa de atrasos',ascending=False)
# Out:
#        Fecha-I  Cantidad_vuelos  Cantidad_atrasos  Tasa de atrasos
# 195 2017-07-15              159                99        62.264151
# 205 2017-07-25              177               109        61.581921
# 190 2017-07-10              198               115        58.080808
# 354 2017-12-21              225               110        48.888889
# 191 2017-07-11              195                93        47.692308
# ..         ...              ...               ...              ...
# 226 2017-08-15              183                11         6.010929
# 79  2017-03-21              167                10         5.988024
# 262 2017-09-20              189                11         5.820106
# 105 2017-04-16              181                 8         4.419890
# 83  2017-03-25              145                 5         3.448276
#
# [365 rows x 4 columns]

# %% [markdown]
# #### Observamos que los 3 valores de tasa de atrasos mas altos se presentan en el mes de Julio, veamos estos valores en un gráfico de serie temporal

# %%
fig = px.line(Fechas
              , x='Fecha-I'
              , y='Tasa de atrasos'
              , markers = True
              )
              

fig.show()

# %% [markdown]
# El mes Julio para el año 2017 se presenta una mayor tasa de atrasos en los vuelos, existe una tendencia al alza, se corrobora la estacionalidad para temporadas y en un menos grado a nivel mes vs mes año anterior.

# %% [markdown]
# #### Calculo de tasa de atrasos por día de la semana

# %%
Dia = datos_test.groupby([
                          #'Des-O'
                          #'OPERA'
                          #'MES',
                          'DIANOM'
                          #'temporada_alta'
                        ],  dropna=False, as_index=False).agg(
    Cantidad_vuelos = ('atraso_15','count'),
    Cantidad_atrasos = ('atraso_15','sum'))
Dia['Tasa de atrasos'] = (Dia['Cantidad_atrasos']/Dia['Cantidad_vuelos'])*100
print(Dia.sort_values('Tasa de atrasos',ascending=False))

fig = px.bar(Dia.sort_values('Tasa de atrasos',ascending=True)
             , y='DIANOM'
             , x='Tasa de atrasos'
             , color='Cantidad_vuelos'
             , color_continuous_scale= 'Bluered'
             , title= 'Tasa de atrasos y cantidad de vuelos según día de la semama'
             , text_auto=True)
             
fig.update_traces( marker_line_color = 'black')
fig.show()
# Out:
#       DIANOM  Cantidad_vuelos  Cantidad_atrasos  Tasa de atrasos
# 6    Viernes            10292              2285        22.201710
# 2      Lunes            10131              2048        20.215181
# 1     Jueves            10251              2045        19.949273
# 4  Miercoles             9722              1661        17.084962
# 3     Martes             9662              1634        16.911613
# 5     Sabado             8352              1363        16.319444
# 0    Domingo             9796              1578        16.108616

# %% [markdown]
# ### Observamos que los dias Viernes son los que presentan mayor tasa de atrasos en cantidad de vuelos

# %% [markdown]
# #### Tasa de atrasos por Temporada

# %%
Temporada = datos_test.groupby([
                          #'Des-O'
                          #'OPERA',
                          #'MES',
                          #'DIA',
                          'temporada_alta'
                        ], dropna=False, as_index=False).agg(
    Cantidad_vuelos = ('atraso_15','count'),
    Cantidad_atrasos = ('atraso_15','sum'))

Temporada['Tasa de atrasos'] = (Temporada['Cantidad_atrasos']/Temporada['Cantidad_vuelos'])*100

Temporada.sort_values('Tasa de atrasos',ascending=False)

def f(row):
    if row == 0:
        val = 'Temporada Baja'
    else:
        val = 'Temporada Alta'
    return val
Temporada['temporada_alta'] = Temporada['temporada_alta'].apply(f)
print(Temporada.sort_values('Tasa de atrasos',ascending=False))



fig = px.bar(Temporada
             , y ='temporada_alta'
             , x ='Tasa de atrasos'
             , color='Cantidad_atrasos'
             , color_continuous_scale= 'sunset'
             , orientation= 'h'
             , title = 'Tasa de atrasos por temporada coloreado por Cantidad de atrasos'
             , text_auto= True
             )

fig.update_traces(marker_line_color = 'black')
fig.show()
# Out:
#    temporada_alta  Cantidad_vuelos  Cantidad_atrasos  Tasa de atrasos
# 1  Temporada Alta            22211              4360        19.629913
# 0  Temporada Baja            45995              8254        17.945429

# %% [markdown]
# #### Observamos que para la temporada alta existe prácticamente la mitad de los vuelos con atrasos que en temporada alta, y las tasas de atrasos son muy parecidos, por lo que podemos decir que en temporada altas son mas eficientes en las salidas de vuelos

# %%
Feriados = datos_test.groupby([
                          #'Des-O'
                          #'OPERA',
                          #'MES',
                          #'DIA',
                          'Feriado'
                        ], dropna=False, as_index=False).agg(
   Cantidad_vuelos = ('atraso_15','count'),
   Cantidad_atrasos = ('atraso_15','sum')
                                            )

Feriados['Tasa de atrasos'] = (Feriados['Cantidad_atrasos']/Feriados['Cantidad_vuelos'])*100

Feriados = Feriados.sort_values('Tasa de atrasos',ascending=False)
print(Feriados.sort_values('Tasa de atrasos',ascending=False))

fig = px.bar(Feriados.sort_values('Tasa de atrasos'
             ,ascending=True)
             , y='Feriado'
             , x='Tasa de atrasos'
             , color= 'Cantidad_atrasos'
             , color_discrete_sequence=['steelblue']
             , text_auto= True)
fig.show()
# Out:
#       Feriado  Cantidad_vuelos  Cantidad_atrasos  Tasa de atrasos
# 1  No Feriado            64973             12114        18.644668
# 0     Feriado             3233               500        15.465512

# %% [markdown]
# #### Las tasas de atrasos en días feriados se presentan en 18.64% para los días no feriados vs 15.46% para los días feriados, y se observa una clara diferencia entre los atrasos de estos tipos de días.

# %% [markdown]
# # Conclusiones
# ### Es relevante la consideración del país de destino (Australia es el con mayor tasa de atrasos vs Panamá como el menor, o viajes nacionales). Así como operadores
# ### Por otra parte, un candidato a incorporar como variable al modelo es la variable creada Feriado, que nos entrega una diferencia en el cálculo de su tasa entre feriado si y feriado no.
# ### También de observaron diferencias en las variables periodo día, día y mes lo que nos indica que la temporalidad de los datos es influyente en el atraso de un vuelo.

# %% [markdown]
# # 4.-  Entrena uno o varios modelos (usando el/los algoritmo(s) que prefieras) para estimar la probabilidad de atraso de un vuelo. Siéntete libre de generar variables adicionales y/o complementar con variables externas

# %% [markdown]
# # Enfocar en probabilidad

# %% [markdown]
# ## MODELACIÓN

# %% [markdown]
# ## Random Forest

# %% [markdown]
# #### Un primera consideración con respecto la cantidad de datos es que la variable a predecir "atrasos" no se encuentra balanceada (18% atrasos), por lo que crearemos un modelo balanceado y otro desbalanceado.
#
# #### Se encoge como primer candidato un árbol de decisión, dada su simpleza de implementación y robustez ante datos outliers, combinaciones de variables, trato con respecto al tipo de dato, entre otros.
#
# #### Nota: Recordar que se hizo un proceso de label encoding de las variables, así como transformamos variables temporales a númericas. Cómo utilizaremos modelos de árboles, no es necesario considerarlas como factores (modelos lineales, redes neuronales, etc.), y se utilizaran directamente en los modelos. De la misma forma, tampoco es necesario estandarizar las variables.

# %%
print(datos_test['atraso_15'].value_counts())
# Out:
# 0    55592
# 1    12614
# Name: atraso_15, dtype: int64

# %% [markdown]
# #### Usaremos técnica llamada "remuestreo" que se utiliza para equilibrar la distribución de clases en un conjunto de datos. En este caso, el conjunto de datos "datos_test" se divide en dos subconjuntos: "datos_no_atraso" y "datos_atraso", según si el valor de la columna "atraso_15" es 0 o 1. El subconjunto "datos_atraso" es remuestreado utilizando la función resample() de scikit-learn, con un tamaño de muestra fijo de 30.000. Reemplazando los datos originales y utilizando una semilla de aleatoriedad especificada en random_state = 666. Finalmente, los dos subconjuntos remuestreados se concatenan en un solo conjunto llamado "data_sampled".

# %%
#Resample
from sklearn.utils import resample


datos_no_atraso = datos_test[datos_test['atraso_15'] == 0]
datos_atraso = datos_test[datos_test['atraso_15'] == 1]

datos_atraso_sampled = resample(datos_atraso, 
                                 replace = True,     
                                 n_samples = 30000,    
                                 random_state = 666) 

data_sampled = pd.concat([datos_no_atraso, datos_atraso_sampled])

# %%
print(data_sampled['atraso_15'].value_counts())
# Out:
# 0    55592
# 1    30000
# Name: atraso_15, dtype: int64

# %% [markdown]
# #### Observamos que los datos del remuestreo genero la clase de atraso los 30.000 datos que pusimos como parametro en la función de remuestreo.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, accuracy_score, confusion_matrix, classification_report,roc_auc_score, roc_curve
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn import preprocessing

le = preprocessing.LabelEncoder()

rf = RandomForestClassifier()
rf1 = RandomForestClassifier()
#sfs = SequentialFeatureSelector(rf)

X = datos_test[[        'OPERA'
                        ,'periodo_dia'
                        ,'DIANOM'
                        ,'Mes_Nombre'
                        ,'temporada_alta'
                        ,'Destino'
                        #, 'hora_dia'
                        , 'hora'
                        , 'minutos'
                        ,'Feriado'
                        ,'TIPOVUELO'
                        ,'País']]
Y = datos_test[['atraso_15']]

# %% [markdown]
# Primero, se importan las librerías necesarias: RandomForestClassifier y las métricas de evaluación como f1_score, accuracy_score, confusion_matrix, classification_report,roc_auc_score y roc_curve.
#
# Luego se importa la librería SequentialFeatureSelector y LabelEncoder, que se usará para codificar las variables categóricas.
#
# Se crea una instancia del modelo RandomForestClassifier, llamada "rf" y "rf1"
#
# También se crea una instancia de SequentialFeatureSelector, llamada "sfs", que se utilizará para seleccionar las características más importantes del conjunto de datos.
#
# Se define la variable X como el conjunto de características (columnas) del conjunto de datos "datos_test" que se utilizarán para entrenar el modelo. Estas características incluyen 'OPERA','periodo_dia', 'DIANOM', 'Mes_Nombre', 'temporada_alta', 'Destino', 'hora', 'minutos', 'Feriado', ]'TIPOVUELO' y 'País'
#
# La variable Y es la columna 'atraso_15' del conjunto de datos, que es la variable objetivo a predecir.

# %%
X1 = data_sampled[[
                'OPERA'
                ,'periodo_dia'
                ,'DIANOM'
                ,'Mes_Nombre'
                ,'temporada_alta'
                ,'Destino'
                #, 'hora_dia'
                , 'hora'
                , 'minutos'
                ,'Feriado'
                ,'TIPOVUELO'
                ,'País']]
Y1 = data_sampled[['atraso_15']]

# %% [markdown]
# generamos el mismo data set pero con las variables remuestreadas, por esto se llamaran  X1 e Y1 los conjuntos de datos.

# %%
# %%capture
X['OPERA'] = le.fit_transform(X['OPERA'])
X['DIANOM'] = le.fit_transform(X['DIANOM'])
X['periodo_dia'] = le.fit_transform(X['periodo_dia'])
X['Mes_Nombre'] = le.fit_transform(X['Mes_Nombre'])
X['temporada_alta'] = le.fit_transform(X['temporada_alta'])
X['Destino'] = le.fit_transform(X['Destino'])
X['Feriado'] = le.fit_transform(X['Feriado'])
X['TIPOVUELO'] = le.fit_transform(X['TIPOVUELO'])
X['País'] = le.fit_transform(X['País'])

X1['OPERA'] = le.fit_transform(X1['OPERA'])
X1['DIANOM'] = le.fit_transform(X1['DIANOM'])
X1['periodo_dia'] = le.fit_transform(X1['periodo_dia'])
X1['Mes_Nombre'] = le.fit_transform(X1['Mes_Nombre'])
X1['temporada_alta'] = le.fit_transform(X1['temporada_alta'])
X1['Destino'] = le.fit_transform(X1['Destino'])
X1['Feriado'] = le.fit_transform(X1['Feriado'])
X1['TIPOVUELO'] = le.fit_transform(X1['TIPOVUELO'])
X1['País'] = le.fit_transform(X1['País'])

# %% [markdown]
# se están codificando las variables categóricas en el conjunto de datos "X" utilizando la instancia de LabelEncoder creada anteriormente. Cada columna especificada ('OPERA', 'DIANOM', 'periodo_dia', 'Mes_Nombre', 'temporada_alta', 'Destino', 'Feriado', 'TIPOVUELO' y 'País') es convertida en una representación numérica, reemplazando los valores originales de las categorías con números enteros.
# También para el conjunto remuestreado

# %% [markdown]
# entrenamos los modelos

# %%
from sklearn.model_selection import train_test_split

# 80 % del conjunto de datos para entrenamiento y 20 % para validacion
X_train, X_test, Y_train, Y_test = train_test_split(
                                              X
                                            , Y
                                            ,test_size=0.2
                                            ,  random_state = 666)

# 80 % del conjunto de datos para entrenamiento y 20 % para validacion
X1_train, X1_test, Y1_train, Y1_test = train_test_split(
                                              X1
                                            , Y1
                                            ,test_size=0.2
                                            ,  random_state = 666)

# %%
# %%capture
rf.fit(X_train,Y_train)
rf1.fit(X1_train,Y1_train)

# %% [markdown]
# #### A medida de comparación de modelos con datos sin remuestreo y modelo con datos remuestrados usaremos dos modelos uno con terminación "1" para mostrar que es con los datos balanceados.

# %%
Y_pred = rf.predict(X_test)

Y1_pred = rf1.predict(X1_test)

# %% [markdown]
# calculo de predicciones de modelos

# %%
print("Reporte de clasificación de modelo desbalanceado")
print(classification_report(Y_test, Y_pred))
print("Reporte de clasificación de modelo balanceado")
print(classification_report(Y1_test, Y1_pred))
# Out:
# Reporte de clasificación de modelo desbalanceado
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.88     11160
#            1       0.37      0.23      0.29      2482
#
#     accuracy                           0.79     13642
#    macro avg       0.60      0.57      0.58     13642
# weighted avg       0.76      0.79      0.77     13642
#
# Reporte de clasificación de modelo balanceado
#               precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84     11203
#            1       0.69      0.75      0.72      5916
#
#     accuracy                           0.80     17119
#    macro avg       0.78      0.79      0.78     17119
# weighted avg       0.80      0.80      0.80     17119

# %% [markdown]
# Observamos que el modelo con los datos originales obtiene una precisión de 0.37 con para la clase 1 (atraso) en cambio el modelo remuestreado obtiene una precisión de 0.69 para la misma clase.
# por lo que es un candidato para elección de modelo.
#
# Por supuesto, que disminuye la precisión y el recall para los casos de no atrasos. Pero el interés primordial es la predicción de atrasos, por lo que esa pequeña disminución de ajuste, nos supone un modelo para nuestros intereses. Subimos considerablemente el f1-score para atrasos (de 0,29 a 0,72)
#
# Lo anterior puede modificable en relación a entender cual es el costo (monetario, de satisfacción de clientes, etc) en gestionar casos erroneos de no atrasos vs erroneos de atrasos.

# %% [markdown]
# #### Generación métricas para Curva de ROC modelos

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.datasets import make_classification


y_score = rf.predict_proba(X_test)[:, 1]

fpr, tpr, thresholds = roc_curve(Y_test,y_score)

# %% [markdown]
# #### Curva ROC modelo desbalanceado

# %%
fig = px.area(
    x=fpr, y=tpr,
    title=f'ROC Curva (AUC={auc(fpr, tpr):.4f})',
    labels=dict(x='False Positive Rate', y='True Positive Rate'), 
    width=700, height=700
)


fig.add_shape(
    type='line', line=dict(dash='dash'),
    x0=0, x1=1, y0=0, y1=1, 
)

fig.update_yaxes(scaleanchor="x", scaleratio=1)
fig.update_xaxes(constrain='domain')
fig.update_traces(patch = {'line':{'color':'#ff2800', 'dash':'dash'}})
fig.show()

# %% [markdown]
# #### Generación metricas para Curva de ROC modelo balanceado

# %%
y1_score = rf1.predict_proba(X1_test)[:, 1]

fpr1, tpr1, thresholds = roc_curve(Y1_test,y1_score)

# %%
Y1_pred = rf1.predict(X1_test)

print(classification_report(Y1_test, Y1_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84     11203
#            1       0.69      0.75      0.72      5916
#
#     accuracy                           0.80     17119
#    macro avg       0.78      0.79      0.78     17119
# weighted avg       0.80      0.80      0.80     17119

# %% [markdown]
# #### Curva ROC modelo balanceado

# %%
fig = px.area(
    x=fpr1, y=tpr1,
    title=f'ROC Curve (AUC={auc(fpr1, tpr1):.4f})',
    labels=dict(x='False Positive Rate', y='True Positive Rate'), 
    width=700, height=700
)


fig.add_shape(
    type='line', line=dict(dash='dash'),
    x0=0, x1=1, y0=0, y1=1, 
)

fig.update_yaxes(scaleanchor="x", scaleratio=1)
fig.update_xaxes(constrain='domain')
fig.update_traces(patch = {'line':{'color':'#ff2800', 'dash':'dash'}})
fig.show()

# %% [markdown]
# El modelo con AUC de 0.86 tiene un mejor rendimiento que el modelo con AUC de 0.65, ya que está asignando con mayor precisión las probabilidades de pertenencia a cada clase. Hay que considerar que no es factible hacer una modificación directa.

# %% [markdown]
# Ahora probaremos el modelo creado partir de los datos balanceados en el conjunto de test con datos no balanceados

# %%
YB_pred = rf1.predict(X_test)

print(classification_report(Y_test, YB_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.88      0.91     11160
#            1       0.58      0.75      0.65      2482
#
#     accuracy                           0.86     13642
#    macro avg       0.76      0.81      0.78     13642
# weighted avg       0.87      0.86      0.86     13642

# %%
yB_score = rf1.predict_proba(X_test)[:, 1]

fprB, tprB, thresholds = roc_curve(Y_test,yB_score)

fig = px.area(
    x=fprB, y=tprB,
    title=f'ROC Curve (AUC={auc(fprB, tprB):.4f})',
    labels=dict(x='False Positive Rate', y='True Positive Rate'), 
    width=700, height=700
)


fig.add_shape(
    type='line', line=dict(dash='dash'),
    x0=0, x1=1, y0=0, y1=1, 
)

fig.update_yaxes(scaleanchor="x", scaleratio=1)
fig.update_xaxes(constrain='domain')
fig.update_traces(patch = {'line':{'color':'#ff2800', 'dash':'dash'}})
fig.show()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from matplotlib import pyplot as plt



# Obtener los nombres de las variables
feature_names = X.columns

# Crear el DataFrame
importancia = {'Feature':feature_names,'Importance':rf1.feature_importances_}
df = pd.DataFrame(importancia)
# Ordenar el DataFrame según la importancia
df.sort_values(by='Importance',ascending=False,inplace=True)
print(df)
fig = px.bar(df.sort_values('Importance', ascending=True)
             , x ='Importance'
             , y ='Feature'
             , orientation= 'h'
             , title = 'Importancia de las variables'
             , text_auto= True
             )

fig.update_traces(marker_line_color = 'black')
fig.show()
# Out:
#            Feature  Importance
# 2           DIANOM    0.234570
# 3       Mes_Nombre    0.192009
# 7          minutos    0.168013
# 6             hora    0.122289
# 5          Destino    0.119374
# 0            OPERA    0.049904
# 4   temporada_alta    0.036239
# 10            País    0.029162
# 8          Feriado    0.021206
# 1      periodo_dia    0.017377
# 9        TIPOVUELO    0.009856

# %% [markdown]
# #### Ahora pasaremos a generar un modelo Random Forest balanceado, mejorando algunos de sus hiper-parametros.

# %% [markdown]
# La función GridSearchCV toma como argumentos el estimador (en este caso, un objeto de RandomForestClassifier llamado "rf1"), un diccionario de parámetros (en este caso, "param_grid") y el número de veces que se va a hacer la validación cruzada (en este caso, "cv = 10").
#
# se especifican dos parámetros para ajustar: "max_features" y "n_estimators", con un rango de valores de 1 a 10 con un paso de 1. La función GridSearchCV probará todas las combinaciones de estos parámetros y seleccionará la mejor combinación según el puntaje obtenido en la validación cruzada.

# %%
from sklearn.model_selection import GridSearchCV

max_features_range = np.arange(1,10,1)
n_estimators_range = np.arange(1,10,1)
param_grid = dict(max_features = max_features_range, n_estimators = n_estimators_range)

grid = GridSearchCV(estimator = rf1, param_grid = param_grid, cv=10)

# %%
# %%capture
grid.fit(X1_train, Y1_train)

# %%
print("Mejor combinacion de hiper-parametros para modelo con balanceo es  %s con precición de  %0.4f"
      % (grid.best_params_, grid.best_score_))
# Out:
# Mejor combinacion de hiper-parametros para modelo con balanceo es  {'max_features': 2, 'n_estimators': 8} con precición de  0.7863

# %% [markdown]
# #### Nuestro nuevo modelo se llamara rf_final y se generara desde la muestra balanceada y con los hiper-parametros optimizados según la grilla grid.

# %%
rf_final = RandomForestClassifier(   max_features = grid.best_params_['max_features']
                                   , n_estimators = grid.best_params_['n_estimators']
                                    )

rf_final.fit(X1_train,Y1_train)

Y1_pred = rf_final.predict(X1_test)
# Out:
# C:\Users\shado\AppData\Local\Temp\ipykernel_26532\818426432.py:5: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().

# %%
Y1_pred = rf1.predict(X1_test)
print("Reporte de clasificación de modelo balanceado")
print(classification_report(Y1_test,Y1_pred))

print("Reporte de clasificación de modelo balanceado y optimizado en los datos test no balanceados")

YF_pred = rf_final.predict(X1_test)

print(classification_report(Y1_test, YF_pred))
# Out:
# Reporte de clasificación de modelo balanceado
#               precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84     11203
#            1       0.69      0.75      0.72      5916
#
#     accuracy                           0.80     17119
#    macro avg       0.78      0.79      0.78     17119
# weighted avg       0.80      0.80      0.80     17119
#
# Reporte de clasificación de modelo balanceado y optimizado en los datos test no balanceados
#               precision    recall  f1-score   support
#
#            0       0.85      0.82      0.84     11203
#            1       0.68      0.73      0.71      5916
#
#     accuracy                           0.79     17119
#    macro avg       0.77      0.78      0.77     17119
# weighted avg       0.79      0.79      0.79     17119

# %% [markdown]
# Es muy importante para el desafio obtener las probabilidades de atraso, no solo la clasificación de esta. Por lo que para usar un modelo balanceado, es necesario corregir las probabilidades, por lo que usaremos la siguiente formula.
#
#  ![image.png](attachment:image.png)

# %% [markdown]
# #### Obtenemos ligeros cambios en las estadísticas de reporte, lo que es de esperarse en las optimizaciones de hiper-parametros

# %% [markdown]
# #### Observamos una mejora en el porcentaje de clasificación correcta que presenta la curva de ROC, por lo que la busqueda y optimización de hiper-parametros funciono correctamente

# %% [markdown]
# # Probaremos el mismo metodo anterior, pero ahora con Xtreme - Gradient Boosted

# %% [markdown]
# ### Xtreme - Gradient Boosted

# %%
# %%capture
import xgboost as xgb

modelo_xgb = xgb.XGBClassifier()

X2 = data_sampled[[      'OPERA'
                        ,'periodo_dia'
                        ,'DIANOM'
                        ,'Mes_Nombre'
                        ,'temporada_alta'
                        ,'Destino'
                        #, 'hora_dia'
                        , 'hora'
                        , 'minutos'
                        ,'Feriado'
                        ,'TIPOVUELO'
                        ,'País']]
Y2 = data_sampled[['atraso_15']]

# %%
# %%capture
X2['OPERA'] = le.fit_transform(X2['OPERA'])
X2['DIANOM'] = le.fit_transform(X2['DIANOM'])
X2['periodo_dia'] = le.fit_transform(X2['periodo_dia'])
X2['Mes_Nombre'] = le.fit_transform(X2['Mes_Nombre'])
X2['temporada_alta'] = le.fit_transform(X2['temporada_alta'])
X2['Destino'] = le.fit_transform(X2['Destino'])
X2['Feriado'] = le.fit_transform(X2['Feriado'])
X2['TIPOVUELO'] = le.fit_transform(X2['TIPOVUELO'])
X2['País'] = le.fit_transform(X2['País'])

# %% [markdown]
# en esta sección se ajustan los datasets de la misma manera del modelo Random Forest

# %%
X2_train, X2_test, Y2_train, Y2_test = train_test_split(
                                                    X2
                                                    ,Y2
                                                    ,test_size=0.2
                                                    , random_state= 666)

# %%
# %%capture
modelo_xgb.fit(X2_train,Y2_train)

# %% [markdown]
# Entrenamos el modelo XGB y obtenemos las siguientes metricas.

# %%
Y2_pred = modelo_xgb.predict(X2_test)

y2_score = modelo_xgb.predict_proba(X2_test)[:, 1]

fpr2, tpr2, thresholds = roc_curve(Y2_test,y2_score)


print("Reporte de clasificación de modelo Gradient boosted balanceado")
print(classification_report(Y2_test,Y2_pred))
# Out:
# Reporte de clasificación de modelo Gradient boosted balanceado
#               precision    recall  f1-score   support
#
#            0       0.75      0.88      0.81     11203
#            1       0.67      0.45      0.54      5916
#
#     accuracy                           0.73     17119
#    macro avg       0.71      0.66      0.67     17119
# weighted avg       0.72      0.73      0.72     17119

# %%
fig = px.area(
    x=fpr2, y=tpr2,
    title=f'ROC Curva (AUC={auc(fpr2, tpr2):.4f})',
    labels=dict(x='False Positive Rate', y='True Positive Rate'), 
    width=700, height=700
)


fig.add_shape(
    type='line', line=dict(dash='dash'),
    x0=0, x1=1, y0=0, y1=1, 
)

fig.update_yaxes(scaleanchor="x", scaleratio=1)
fig.update_xaxes(constrain='domain')
fig.update_traces(patch = {'line':{'color':'#50339E', 'dash':'dash'}})
fig.show()

# %% [markdown]
# Usando este modelo se obtiene una curva de ROC con menos que el modelo Random forest, por lo que nos indica que esta sección tiene un desempeño menor que el modelo anterior.
# también usaremos el mismo método de ajuste de grilla para optimizar el modelo y comparar métricas con el anterior.

# %%
from sklearn.model_selection import GridSearchCV

max_features_range = np.arange(1,10,1)
n_estimators_range = np.arange(1,10,1)
param_grid = dict(max_features = max_features_range, n_estimators = n_estimators_range)

grid = GridSearchCV(estimator = modelo_xgb, param_grid = param_grid, cv=10)

# %%
# %%capture
grid.fit(X2_train, Y2_train)

# %%
print("Mejor combinacion de hiper-parametros para modelo con balanceo es  %s con precición de  %0.4f"
      % (grid.best_params_, grid.best_score_))
# Out:
# Mejor combinacion de hiper-parametros para modelo con balanceo es  {'max_features': 1, 'n_estimators': 9} con precición de  0.6921

# %%
modelo_xgb_final = xgb.XGBClassifier( max_features = grid.best_params_['max_features']
                                   , n_estimators = grid.best_params_['n_estimators']
                                    )
modelo_xgb_final.fit(X2_train,Y2_train)

Y2_pred = modelo_xgb_final.predict(X2_test)
# Out:
# [23:59:27] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-030221e36e1a46bfb-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "max_features" } are not used.

# %%
print("Reporte de clasificación de modelo balanceado y optimizado")

print(classification_report(Y2_test,Y2_pred))

y2_score = modelo_xgb_final.predict_proba(X2_test)[:, 1]

fpr_final, tpr_final, thresholds = roc_curve(Y2_test,y2_score)


print("Reporte de clasificación de modelo balanceado y optimizado (Random Forest)")
print(classification_report(Y1_test,Y1_pred))
# Out:
# Reporte de clasificación de modelo balanceado y optimizado
#               precision    recall  f1-score   support
#
#            0       0.70      0.94      0.80     11203
#            1       0.68      0.24      0.36      5916
#
#     accuracy                           0.70     17119
#    macro avg       0.69      0.59      0.58     17119
# weighted avg       0.69      0.70      0.65     17119
#
# Reporte de clasificación de modelo balanceado y optimizado (Random Forest)
#               precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84     11203
#            1       0.69      0.75      0.72      5916
#
#     accuracy                           0.80     17119
#    macro avg       0.78      0.79      0.78     17119
# weighted avg       0.80      0.80      0.80     17119

# %% [markdown]
# en el reporte observamos que la precision, recall, f1-score menores al modelo Random Forest ajustado anteriomente.
# Por lo que elegiremos este modelo.

# %%
Probabilidad = pd.DataFrame(rf1.predict_proba(X_test))
Probabilidad
# Out:
#               0         1
# 0      0.981250  0.018750
# 1      0.930000  0.070000
# 2      0.990000  0.010000
# 3      0.911167  0.088833
# 4      0.951000  0.049000
# ...         ...       ...
# 13637  0.084261  0.915739
# 13638  1.000000  0.000000
# 13639  0.983333  0.016667
# 13640  0.917465  0.082535
# 13641  0.127778  0.872222
#
# [13642 rows x 2 columns]

# %% [markdown]
# # Conclusión:
# ### De los dos modelos probados en este notebook, elegiremos el modelo de árboles Random Forest ya que fue el que mejor resultados obtuvo con el procesamiento de datos que ejecutamos en este notebook.
#
# ### Las variables usadas para la confeccioón del modelo y las que se adjuntaron de forma externa, ayudaron a crear un modleo sencillo y robusto para la prediccion de atrasos en los vuelos segun, 'OPERA', 'periodo_dia', 'DIANOM', 'Mes_Nombre', 'temporada_alta', 'Destino', 'hora', 'minutos', 'Feriado', 'TIPOVUELO', 'País'. de esta manera obtener una predicion de la probabilidad de tener un vuelo atrasado.

# %% [markdown]
# ## Trabajos futuros
#
# Utilizar variables temporales (atraso móvil por operador en X viajes anteriores, así mismo para todos los vuelos)
#
# Información de distancia a Destino
# Información del piloto o tripulación
# Condiciones climáticas
# tipo de avión
# composición de pasajeros (edad, discapacidad, etc.)
